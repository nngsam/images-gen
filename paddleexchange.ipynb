# %%
# !pip install paddle
# !pip install paddlepaddle
# !pip install paddleocr
# Out:
# ...
#   Obtaining dependency information for paddlepaddle from https://files.pythonhosted.org/packages/60/50/701f6cec187d4fe2ade62e0ed317e6acc12d80d687e75de709e571919044/paddlepaddle-2.5.2-cp39-cp39-manylinux1_x86_64.whl.metadata
#   Using cached paddlepaddle-2.5.2-cp39-cp39-manylinux1_x86_64.whl.metadata (8.5 kB)
# ...
#   Obtaining dependency information for httpx from https://files.pythonhosted.org/packages/82/61/a5fca4a1e88e40969bbd0cf0d981f3aa76d5057db160b94f49603fc18740/httpx-0.25.1-py3-none-any.whl.metadata
#   Using cached httpx-0.25.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Obtaining dependency information for protobuf>=3.20.2 from https://files.pythonhosted.org/packages/ae/5b/7ed02a9b8e752c8f7bca8661779c0275b9e3e6a903a3045e6da51f796dda/protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl.metadata
# ...

# %%
import numpy as np
from PIL import Image
from paddle.vision import image_load, set_image_backend

# %%
fake_img = Image.fromarray((np.random.random((32, 32, 3)) * 255).astype('uint8'))

path = '/home/dslab/code/new_text/text_renderer/example_data/effect_layout_image/bg_and_text_mask/images/000000000.jpg'
fake_img.save(path)

set_image_backend('pil')

pil_img = image_load(path).convert('RGB')

# should be PIL.Image.Image
print(type(pil_img))

#use opencv as backend
set_image_backend('cv2')

np_img = image_load(path)
# should get numpy.ndarray
print(type(np_img))
# Out:
# <class 'PIL.Image.Image'>
# <class 'numpy.ndarray'>

# %%
np_img
# Out:
# array([[[ 72, 118,  99],
#         [ 46,  68,  49],
#         [204, 174, 157],
#         ...,
#         [ 79,  59,  12],
#         [102,  38,   0],
#         [236, 149, 109]],
#
#        [[131, 169, 174],
#         [203, 216, 224],
#         [107,  73,  83],
#         ...,
#         [102,  98,  63],
#         [128,  92,  54],
#         [201, 150, 110]],
#
#        [[ 95, 118, 174],
#         [174, 175, 233],
#         [124,  81, 144],
#         ...,
#         [ 73, 101,  88],
#         [ 54,  76,  47],
#         [228, 246, 209]],
#
#        ...,
#
#        [[ 64,  50,  52],
#         [198, 172, 186],
#         [119,  66, 106],
#         ...,
#         [214, 174, 202],
#         [128, 106, 118],
#         [117, 104, 106]],
#
#        [[141, 152, 120],
#         [131, 140, 119],
#         [106, 109, 113],
#         ...,
#         [ 88,  62,  92],
#         [189, 209, 190],
#         [  0,  45,   2]],
#
#        [[ 92, 114,  65],
#         [183, 210, 171],
#         [ 79, 111,  94],
# ...

# %%
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>
